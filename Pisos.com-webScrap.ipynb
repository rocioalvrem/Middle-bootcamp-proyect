# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
# Lista de distritos


#'https://www.fotocasa.es/es/comprar/viviendas/madrid-capital/arguelles/l?maxPrice=2500000&minPrice=75000'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
}

#response = requests.get(url, headers=headers)


# Encabezados para la solicitud
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# Almacena los datos recopilados
all_data_2 = []

# Bucle sobre los distritos

    # Formatea la URL para el distrito actual
url = 'https://www.pisos.com/venta/pisos-goya/hasta-600000/'
        ##+ tramo

    # Realiza la solicitud
       # response = requests.get(url, headers=headers)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers)

print(f"URL: {url}\nStatus Code: {response.status_code}")

print(f'URL: {url}')
print(f'Status Code: {response.status_code}')

if response.status_code == 200:
                    # Parsea el contenido de la página con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

                    # Encuentra todos los elementos <a> con la clase "item-link"
    title_elements = soup.find_all('a', class_='ad-preview__title')
    prices_elements = soup.find_all('span', class_='ad-preview__price')
    bathrooms_elements =soup.find_all('p', class_='ad-preview__char p-sm')
    surface_elements = soup.find_all('p', class_='ad-preview__char p-sm')
                    #garages_elements = soup.find_all('p', class_='ad-preview__char p-sm')
                    #elevator_elements = soup.find_all('span', class_='re-CardFeaturesWithIcons-feature-icon re-CardFeaturesWithIcons-feature-icon--elevator')
    rooms_elements = soup.find_all('p', class_='ad-preview__char p-sm')
    details_elements = soup.find_all('p', class_='ad-preview__description')


                    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices_elements]
    bathrooms = [bathroom.text.strip() for bathroom in bathrooms_elements]
    rooms = [room.text.strip() if room else None for room in rooms_elements]
    details = [detail.text.strip() if detail else None for detail in details_elements]
    surfaces = [surface.text.strip() if surface else None for surface in surface_elements]
                    #elevators = [elevator.text.strip() if detail else None for elevator in elevator_elements]
                    #air_conditioners = [air_conditioner.text.strip() if air_conditioner else None for air_conditioner in air_conditioner_elements]
                    # Encuentra la longitud máxima
    max_length = max(len(titles), len(prices),len(rooms), len(bathrooms), len(details), len(surfaces))

                    # Rellena las listas con valores nulos si es necesario
    titles += [None] * (max_length - len(titles))
    prices += [None] * (max_length - len(prices))
    bathrooms += [None] * (max_length - len((bathrooms)))
    rooms += [None] * (max_length - len((rooms)))
    surfaces += [None] * (max_length - len(surfaces))
    details += [None] * (max_length - len(details))


                    # Crea un DataFrame de pandas
    data_2 = pd.DataFrame({
        'url': [url] * max_length,
        'Title': titles,
        'Price': prices,
        'Bathrooms':bathrooms,
        'Description': details,
        'Surface': surfaces,
        'Rooms': rooms

           })

                    # Muestra el DataFrame
    print(data_2)

                    # Almacena los datos en la lista
    all_data_2.append(data_2)

    if not title_elements:
                        print("No se encontraron elementos con la clase 'item-link'.\n")

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_2 = pd.concat(all_data_2, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
final_data_2
# Out:
# URL: https://www.pisos.com/venta/pisos-goya/hasta-600000/
# Status Code: 200
# URL: https://www.pisos.com/venta/pisos-goya/hasta-600000/
# Status Code: 200
#                                                    url  \
# 0    https://www.pisos.com/venta/pisos-goya/hasta-6...
# 1    https://www.pisos.com/venta/pisos-goya/hasta-6...
# 2    https://www.pisos.com/venta/pisos-goya/hasta-6...
# 3    https://www.pisos.com/venta/pisos-goya/hasta-6...
# 4    https://www.pisos.com/venta/pisos-goya/hasta-6...
# ..                                                 ...
# 111  https://www.pisos.com/venta/pisos-goya/hasta-6...
# 112  https://www.pisos.com/venta/pisos-goya/hasta-6...
# 113  https://www.pisos.com/venta/pisos-goya/hasta-6...
# 114  https://www.pisos.com/venta/pisos-goya/hasta-6...
# 115  https://www.pisos.com/venta/pisos-goya/hasta-6...
#
#                                  Title      Price  Bathrooms  \
# 0                    Piso en Salamanca  570.000 €     1 hab.
# ...

# %%
final_data_2.to_excel('goya_pisos.xlsx')

# %%
#'https://www.fotocasa.es/es/comprar/viviendas/madrid-capital/arguelles/l?maxPrice=2500000&minPrice=75000'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
}

#response = requests.get(url, headers=headers)


# Encabezados para la solicitud
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# Almacena los datos recopilados
all_data_3 = []

# Bucle sobre los distritos

    # Formatea la URL para el distrito actual
url = 'https://www.pisos.com/venta/pisos-madrid_capital_chamartin/'
        ##+ tramo

    # Realiza la solicitud
       # response = requests.get(url, headers=headers)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers)

print(f"URL: {url}\nStatus Code: {response.status_code}")

print(f'URL: {url}')
print(f'Status Code: {response.status_code}')

if response.status_code == 200:
                    # Parsea el contenido de la página con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

                    # Encuentra todos los elementos <a> con la clase "item-link"
    title_elements = soup.find_all('a', class_='ad-preview__title')
    prices_elements = soup.find_all('span', class_='ad-preview__price')
    bathrooms_elements =soup.find_all('p', class_='ad-preview__char p-sm')
    surface_elements = soup.find_all('p', class_='ad-preview__char p-sm')
                    #garages_elements = soup.find_all('p', class_='ad-preview__char p-sm')
                    #elevator_elements = soup.find_all('span', class_='re-CardFeaturesWithIcons-feature-icon re-CardFeaturesWithIcons-feature-icon--elevator')
    rooms_elements = soup.find_all('p', class_='ad-preview__char p-sm')
    details_elements = soup.find_all('p', class_='ad-preview__description')


                    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices_elements]
    bathrooms = [bathroom.text.strip() for bathroom in bathrooms_elements]
    rooms = [room.text.strip() if room else None for room in rooms_elements]
    details = [detail.text.strip() if detail else None for detail in details_elements]
    surfaces = [surface.text.strip() if surface else None for surface in surface_elements]
                    #elevators = [elevator.text.strip() if detail else None for elevator in elevator_elements]
                    #air_conditioners = [air_conditioner.text.strip() if air_conditioner else None for air_conditioner in air_conditioner_elements]
                    # Encuentra la longitud máxima
    max_length = max(len(titles), len(prices),len(rooms), len(bathrooms), len(details), len(surfaces))

                    # Rellena las listas con valores nulos si es necesario
    titles += [None] * (max_length - len(titles))
    prices += [None] * (max_length - len(prices))
    bathrooms += [None] * (max_length - len((bathrooms)))
    rooms += [None] * (max_length - len((rooms)))
    surfaces += [None] * (max_length - len(surfaces))
    details += [None] * (max_length - len(details))


                    # Crea un DataFrame de pandas
    data_3 = pd.DataFrame({
        'url': [url] * max_length,
        'Title': titles,
        'Price': prices,
        'Bathrooms':bathrooms,
        'Description': details,
        'Surface': surfaces,
        'Rooms': rooms

           })

                    # Muestra el DataFrame
    print(data_3)

                    # Almacena los datos en la lista
    all_data_3.append(data_3)

    if not title_elements:
                        print("No se encontraron elementos con la clase 'item-link'.\n")

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_3 = pd.concat(all_data_3, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
final_data_3
# Out:
# URL: https://www.pisos.com/venta/pisos-madrid_capital_chamartin/
# Status Code: 200
# URL: https://www.pisos.com/venta/pisos-madrid_capital_chamartin/
# Status Code: 200
#                                                    url  \
# 0    https://www.pisos.com/venta/pisos-madrid_capit...
# 1    https://www.pisos.com/venta/pisos-madrid_capit...
# 2    https://www.pisos.com/venta/pisos-madrid_capit...
# 3    https://www.pisos.com/venta/pisos-madrid_capit...
# 4    https://www.pisos.com/venta/pisos-madrid_capit...
# ..                                                 ...
# 107  https://www.pisos.com/venta/pisos-madrid_capit...
# 108  https://www.pisos.com/venta/pisos-madrid_capit...
# 109  https://www.pisos.com/venta/pisos-madrid_capit...
# 110  https://www.pisos.com/venta/pisos-madrid_capit...
# 111  https://www.pisos.com/venta/pisos-madrid_capit...
#
#                                    Title        Price  Bathrooms  \
# 0     Piso en calle del Duque de Sevilla  1.075.000 €    3 habs.
# ...

# %%
final_data_3.to_excel('chamartin_pisos.xlsx')

# %%
final_data_4.to_excel('retiro_pisos.xlsx')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL and headers
url = 'https://www.pisos.com/venta/pisos-madrid_capital_retiro/hasta-1000000/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
}

# Response
response = requests.get(url, headers=headers)

print(f'URL: {url}')
print(f'Status Code: {response.status_code}')

# Almacena los datos recopilados
all_data_4 = []

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parsea el contenido de la página con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encuentra todos los elementos <a> con la clase "ad-preview__title"
    title_elements = soup.find_all('a', class_='ad-preview__title')
    prices_elements = soup.find_all('span', class_='ad-preview__price')
    details_elements = soup.find_all('p', class_='ad-preview__char p-sm')

    # Initialize variables to store data
    rooms = None
    bathrooms = None
    surface = None
    floor = None

    # Loop through <p> elements and extract information
    for p in details_elements:
        text = p.text.strip()

        if 'hab.' in text:
            rooms = text
        elif 'baño' in text:
            bathrooms = text
        elif 'm²' in text:
            surface = text
        elif 'planta' in text:
            floor = text

    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices_elements]

    # Crea un DataFrame de pandas
    data_4 = pd.DataFrame({
        'url': [url] * len(titles),
        'Title': titles,
        'Price': prices,
        'Rooms': [rooms] * len(titles),
        'Bathrooms': [bathrooms] * len(titles),
        'Surface': [surface] * len(titles),
        'Floors': [floor] * len(titles),
    })

    # Muestra el DataFrame
    print(data_4)

    # Almacena los datos en la lista
    all_data_4.append(data_4)

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_4 = pd.concat(all_data_4, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
print(final_data_4)
# Out:
# URL: https://www.pisos.com/venta/pisos-madrid_capital_retiro/hasta-1000000/
# Status Code: 200
#                                                   url  \
# 0   https://www.pisos.com/venta/pisos-madrid_capit...
# 1   https://www.pisos.com/venta/pisos-madrid_capit...
# 2   https://www.pisos.com/venta/pisos-madrid_capit...
# 3   https://www.pisos.com/venta/pisos-madrid_capit...
# 4   https://www.pisos.com/venta/pisos-madrid_capit...
# 5   https://www.pisos.com/venta/pisos-madrid_capit...
# 6   https://www.pisos.com/venta/pisos-madrid_capit...
# 7   https://www.pisos.com/venta/pisos-madrid_capit...
# 8   https://www.pisos.com/venta/pisos-madrid_capit...
# 9   https://www.pisos.com/venta/pisos-madrid_capit...
# 10  https://www.pisos.com/venta/pisos-madrid_capit...
# 11  https://www.pisos.com/venta/pisos-madrid_capit...
# 12  https://www.pisos.com/venta/pisos-madrid_capit...
# 13  https://www.pisos.com/venta/pisos-madrid_capit...
# 14  https://www.pisos.com/venta/pisos-madrid_capit...
# ...

# %%
final_data_4.to_excel('retiro_pisos.xlsx')

# %%
url = 'https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/desde-180000/hasta-900000/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
}

# Response
response = requests.get(url, headers=headers)

print(f'URL: {url}')
print(f'Status Code: {response.status_code}')

# Almacena los datos recopilados
all_data_5 = []

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parsea el contenido de la página con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encuentra todos los elementos <a> con la clase "ad-preview__title"
    title_elements = soup.find_all('a', class_='ad-preview__title')
    prices_elements = soup.find_all('span', class_='ad-preview__price')
   # details_elements = soup.find_all('p', class_='ad-preview__char p-sm')
    districts_elements =soup.find_all('p', class_='p-sm')

    # Initialize variables to store data
    rooms = None
    bathrooms = None
    surface = None
    floor = None

    # Loop through <p> elements and extract information
    for p in details_elements:
        text = p.text.strip()

        if 'hab.' in text:
            rooms = text
        elif 'baño' in text:
            bathrooms = text
        elif 'm²' in text:
            surface = text
        elif 'planta' in text:
            floor = text

    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices_elements]
    districts = [district.text.strip() for district in districts_elements]

    # Crea un DataFrame de pandas
    data_5 = pd.DataFrame({
        'url': [url] * len(titles),
        'Title': titles,
        'Price': prices,
        'Rooms': [rooms] * len(titles),
        'Bathrooms': [bathrooms] * len(titles),
        'Surface': [surface] * len(titles),
        'Floors': [floor] * len(titles),
        'District':districts
    })
    print(f"Length of titles: {len(titles)}")
    print(f"Length of prices: {len(prices)}")
    print(f"Length of rooms: {len([rooms] * len(titles))}")
    print(f"Length of bathrooms: {len([bathrooms] * len(titles))}")
    print(f"Length of surface: {len([surface] * len(titles))}")
    print(f"Length of floor: {len([floor] * len(titles))}")
    print(f"Length of districts: {len(districts)}")

    # Muestra el DataFrame
    print(data_5)

    # Almacena los datos en la lista
    all_data_5.append(data_5)

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_5 = pd.concat(all_data_5, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
print(final_data_5)
# Out:
# URL: https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/desde-180000/hasta-900000/
# Status Code: 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7f882737d022> in <module>
#      57         'Surface': [surface] * len(titles),
#      58         'Floors': [floor] * len(titles),
# ---> 59         'District':districts
#      60     })
#      61     print(f"Length of titles: {len(titles)}")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ...

# %%
url = 'https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/desde-180000/hasta-400000/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
}

# Response
response = requests.get(url, headers=headers)

print(f'URL: {url}')
print(f'Status Code: {response.status_code}')

# Almacena los datos recopilados
all_data_5 = []

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parsea el contenido de la página con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encuentra todos los elementos <a> con la clase "ad-preview__title"
    title_elements = soup.find_all('a', class_='ad-preview__title')
    prices_elements = soup.find_all('span', class_='ad-preview__price')
    #details_elements = soup.find_all('p', class_='ad-preview__char p-sm')
    districts_elements = soup.find_all('p', class_='p-sm')

    # Initialize variables to store data
    rooms = None
    bathrooms = None
    surface = None
    floor = None

    # Loop through <p> elements and extract information
     for p in details_elements:
         text = p.text.strip()

         if 'hab.' in text:
             rooms = text
    #     elif 'baño' in text:
    #         bathrooms = text
    #     elif 'm²' in text:
    #         surface = text
    #     elif 'planta' in text:
    #         floor = text

    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices_elements]
    districts = [district.text.strip() for district in districts_elements]

    # Crea un DataFrame de pandas
    data_5 = pd.DataFrame({
        'url': [url] * len(titles),
        'Title': titles,
        'Price': prices,
        'Rooms': [rooms] * len(titles),
        'Bathrooms': [bathrooms] * len(titles),
        'Surface': [surface] * len(titles),
        'Floors': [floor] * len(titles),
        'District': districts  # Use the districts list directly without multiplication
    })


    # Muestra el DataFrame
    print(data_5)

    # Almacena los datos en la lista
    all_data_5.append(data_5)

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_5 = pd.concat(all_data_5, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
print(final_data_5)
# Out:
# URL: https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/desde-180000/hasta-400000/
# Status Code: 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c6672f7a45a5> in <module>
#      57         'Surface': [surface] * len(titles),
#      58         'Floors': [floor] * len(titles),
# ---> 59         'District': districts  # Use the districts list directly without multiplication
#      60     })
#      61
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL and headers
url = 'https://www.pisos.com/venta/pisos-madrid_capital_retiro/hasta-1000000/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
}

# Response
response = requests.get(url, headers=headers)

print(f'URL: {url}')
print(f'Status Code: {response.status_code}')

# Almacena los datos recopilados
all_data_4 = []

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parsea el contenido de la página con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encuentra todos los elementos <a> con la clase "ad-preview__title"
    title_elements = soup.find_all('a', class_='ad-preview__title')
    prices_elements = soup.find_all('span', class_='ad-preview__price')
    details_elements = soup.find_all('p', class_='ad-preview__char p-sm')

    # Initialize variables to store data
    rooms = None
    bathrooms = None
    surface = None
    floor = None

    # Loop through <p> elements and extract information
    for p in details_elements:
        text = p.text.strip()

        if 'hab.' in text:
            rooms = text
        elif 'baño' in text:
            bathrooms = text
        elif 'm²' in text:
            surface = text
        elif 'planta' in text:
            floor = text

    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices_elements]

    # Crea un DataFrame de pandas
    data_4 = pd.DataFrame({
        'url': [url] * len(titles),
        'Title': titles,
        'Price': prices,
        'Rooms': [rooms] * len(titles),
        'Bathrooms': [bathrooms] * len(titles),
        'Surface': [surface] * len(titles),
        'Floors': [floor] * len(titles),
    })

    # Muestra el DataFrame
    print(data_4)

    # Almacena los datos en la lista
    all_data_4.append(data_4)

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_4 = pd.concat(all_data_4, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
print(final_data_4)
