# %%
#import asyncio
import json
import re

from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.idealista.com/venta-viviendas/madrid-madrid/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
}

response = requests.get(url, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="es" env="es" username="" data-userauth="false" class="">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <title>Casas y pisos en Madrid &#8212; idealista</title>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <meta name="description" content="19.836 anuncios de casas y pisos en Madrid, a partir de 12.000 euros. Casas y pisos en Madrid de particulares y agencias inmobiliarias.">
# <meta name="author" content="idealista.com">
# <meta http-equiv="cleartype" content="on">
# <meta name="pragma" content="no-cache"/>
# <meta http-equiv="Pragma" content="no-cache"/>
# <meta http-equiv="Expires" content="Fri, 01 Jan 1990 00:00:00 GMT"/>
# <meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"/>
# <script src="https://st3.idealista.com/static/common/js/lib/jquery/jquery-1.10.2.js" defer></script>
# ...

# %%
response = requests.get(url, headers=headers)

print(response.status_code)
print(response.text)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encuentra todos los elementos <a> con la clase "item-link"
    
    title_elements = soup.find_all('a', class_='item-link')
    prices = soup.find_all('span', class_='item-price h2-simulated')
    currencies = soup.find_all('span', class_='txt-big')
    garages = soup.find_all('span', class_='item-parking')
    descriptions = soup.find_all('p', class_='ellipsis')
    details = soup.find_all('span', class_='item-detail-char')

    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices]
    currencies = [currency.text.strip() for currency in currencies]
    garages = [garage.text.strip() if garage else None for garage in garages]
    descriptions = [desc.text.strip() if desc else None for desc in descriptions]
    details = [detail.text.strip() if detail else None for detail in details]

    # Encuentra la longitud máxima
    max_length = max(len(titles), len(prices), len(currencies), len(garages), len(descriptions), len(details))

    # Rellena las listas con valores nulos si es necesario
    titles += [None] * (max_length - len(titles))
    prices += [None] * (max_length - len(prices))
    currencies += [None] * (max_length - len(currencies))
    garages += [None] * (max_length - len(garages))
    descriptions += [None] * (max_length - len(descriptions))
    details += [None] * (max_length - len(details))

    # Crea un DataFrame de pandas
    data = pd.DataFrame({
        'url': url,
        'Title': titles,
        'Price': prices,
        'Currency': currencies,
        'Garage': garages,
        'Description': descriptions,
        'Details': details
    })

    # Muestra el DataFrame
    print(data)

    if not title_elements:
        print("No se encontraron elementos con la clase 'item-link'.")

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}")
# Out:
#                                                   url  \
# 0   https://www.idealista.com/venta-viviendas/madr...
# 1   https://www.idealista.com/venta-viviendas/madr...
# 2   https://www.idealista.com/venta-viviendas/madr...
# 3   https://www.idealista.com/venta-viviendas/madr...
# 4   https://www.idealista.com/venta-viviendas/madr...
# 5   https://www.idealista.com/venta-viviendas/madr...
# 6   https://www.idealista.com/venta-viviendas/madr...
# 7   https://www.idealista.com/venta-viviendas/madr...
# 8   https://www.idealista.com/venta-viviendas/madr...
# 9   https://www.idealista.com/venta-viviendas/madr...
# 10  https://www.idealista.com/venta-viviendas/madr...
# 11  https://www.idealista.com/venta-viviendas/madr...
# 12  https://www.idealista.com/venta-viviendas/madr...
# 13  https://www.idealista.com/venta-viviendas/madr...
# 14  https://www.idealista.com/venta-viviendas/madr...
# 15  https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
distritos = ['Carabanchel', 'Ciudad Lineal', 'Otro', 'Latina', 'Villaverde', 'Retiro', 'Arganzuela', 'Usera', 'Vicálvaro', 'Fuencarral-El Pardo', 'Moncloa-Aravaca', 'Hortaleza', 'Tetuán', 'Chamberí', 'Moratalaz', 'Centro', 'Puente de Vallecas', 'San Blás-Canillejas', 'B.Salamanca', 'Barajas', 'Villa de Vallecas', 'Chamartín']

url_base = 'https://www.idealista.com/venta-viviendas/madrid/'

# Generar las URLs para cada distrito
urls_distritos = [url_base + distrito.replace(' ', '_').lower() + '/' for distrito in distritos]

# Mostrar las URLs generadas
for url_distrito in urls_distritos:
    print(url_distrito)
# Out:
# https://www.idealista.com/venta-viviendas/madrid/carabanchel/
# https://www.idealista.com/venta-viviendas/madrid/ciudad_lineal/
# https://www.idealista.com/venta-viviendas/madrid/otro/
# https://www.idealista.com/venta-viviendas/madrid/latina/
# https://www.idealista.com/venta-viviendas/madrid/villaverde/
# https://www.idealista.com/venta-viviendas/madrid/retiro/
# https://www.idealista.com/venta-viviendas/madrid/arganzuela/
# https://www.idealista.com/venta-viviendas/madrid/usera/
# https://www.idealista.com/venta-viviendas/madrid/vicálvaro/
# https://www.idealista.com/venta-viviendas/madrid/fuencarral-el_pardo/
# https://www.idealista.com/venta-viviendas/madrid/moncloa-aravaca/
# https://www.idealista.com/venta-viviendas/madrid/hortaleza/
# https://www.idealista.com/venta-viviendas/madrid/tetuán/
# https://www.idealista.com/venta-viviendas/madrid/chamberí/
# https://www.idealista.com/venta-viviendas/madrid/moratalaz/
# https://www.idealista.com/venta-viviendas/madrid/centro/
# ...

# %%
url_carabanchel = 'https://www.idealista.com/venta-viviendas/madrid/carabanchel/'
url_='https://www.idealista.com/venta-viviendas/madrid/'
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encuentra todos los elementos <a> con la clase "item-link"
    title_elements = soup.find_all('a', class_='item-link')
    prices = soup.find_all('span', class_='item-price h2-simulated')
    currencies = soup.find_all('span', class_='txt-big')
    garages = soup.find_all('span', class_='item-parking')
    descriptions = soup.find_all('p', class_='ellipsis')
    details = soup.find_all('span', class_='item-detail-char')

    # Almacena los datos en listas
    titles = [title.text.strip() for title in title_elements]
    prices = [price.text.strip() for price in prices]
    currencies = [currency.text.strip() for currency in currencies]
    garages = [garage.text.strip() if garage else None for garage in garages]
    descriptions = [desc.text.strip() if desc else None for desc in descriptions]
    details = [detail.text.strip() if detail else None for detail in details]

    # Encuentra la longitud máxima
    max_length = max(len(titles), len(prices), len(currencies), len(garages), len(descriptions), len(details))

    # Rellena las listas con valores nulos si es necesario
    titles += [None] * (max_length - len(titles))
    prices += [None] * (max_length - len(prices))
    currencies += [None] * (max_length - len(currencies))
    garages += [None] * (max_length - len(garages))
    descriptions += [None] * (max_length - len(descriptions))
    details += [None] * (max_length - len(details))

    # Crea un DataFrame de pandas
    data_carabanchel = pd.DataFrame({
        'Title': titles,
        'Price': prices,
        'Currency': currencies,
        'Garage': garages,
        'Description': descriptions,
        'Details': details
    })

    # Muestra el DataFrame
    print(data_carabanchel)

    if not title_elements:
        print("No se encontraron elementos con la clase 'item-link'.")

else:
    print(f"Error al obtener la página. Código de estado: {response.status_code}")

# %%
# Lista de distritos
distritos = ['Carabanchel', 'Ciudad Lineal', 'Otro', 'Latina', 'Villaverde', 'Retiro', 'Arganzuela', 'Usera', 'Vicálvaro', 'Fuencarral-El Pardo', 'Moncloa-Aravaca', 'Hortaleza', 'Tetuán', 'Chamberí', 'Moratalaz', 'Centro', 'Puente de Vallecas', 'San Blás-Canillejas', 'B.Salamanca', 'Barajas', 'Villa de Vallecas', 'Chamartín']

# URL base
url_base = 'https://www.idealista.com/venta-viviendas/madrid/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
}

#response = requests.get(url, headers=headers)

print(response.status_code)
print(response.text)
# Encabezados para la solicitud
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# Almacena los datos recopilados
all_data = []

# Bucle sobre los distritos
for distrito in distritos:
    # Formatea la URL para el distrito actual
    url = url_base + distrito.replace(' ', '_').lower() + '/'

    # Realiza la solicitud
    response = requests.get(url, headers=headers)

    print(f'URL: {url}')
    print(f'Status Code: {response.status_code}')

    if response.status_code == 200:
        # Parsea el contenido de la página con BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Encuentra todos los elementos <a> con la clase "item-link"
        title_elements = soup.find_all('a', class_='item-link')
        prices = soup.find_all('span', class_='item-price h2-simulated')
        currencies = soup.find_all('span', class_='txt-big')
        garages = soup.find_all('span', class_='item-parking')
        descriptions = soup.find_all('p', class_='ellipsis')
        details = soup.find_all('span', class_='item-detail-char')

        # Almacena los datos en listas
        titles = [title.text.strip() for title in title_elements]
        prices = [price.text.strip() for price in prices]
        currencies = [currency.text.strip() for currency in currencies]
        garages = [garage.text.strip() if garage else None for garage in garages]
        descriptions = [desc.text.strip() if desc else None for desc in descriptions]
        details = [detail.text.strip() if detail else None for detail in details]

        # Encuentra la longitud máxima
        max_length = max(len(titles), len(prices), len(currencies), len(garages), len(descriptions), len(details))

        # Rellena las listas con valores nulos si es necesario
        titles += [None] * (max_length - len(titles))
        prices += [None] * (max_length - len(prices))
        currencies += [None] * (max_length - len(currencies))
        garages += [None] * (max_length - len(garages))
        descriptions += [None] * (max_length - len(descriptions))
        details += [None] * (max_length - len(details))

        # Crea un DataFrame de pandas
        data = pd.DataFrame({
            'url': [url] * max_length,
            'Title': titles,
            'Price': prices,
            'Currency': currencies,
            'Garage': garages,
            'Description': descriptions,
            'Details': details
        })

        # Muestra el DataFrame
        print(data)

        # Almacena los datos en la lista
        all_data.append(data)

        if not title_elements:
            print("No se encontraron elementos con la clase 'item-link'.\n")

    else:
        print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data = pd.concat(all_data, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
final_data
# Out:
# 403
# <html><head><title>idealista.com</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script data-cfasync="false">var dd={'rt':'c','cid':'AHrlqAAAAAMAzZYHPq7qNxEAAotiSQ==','hsh':'AC81AADC3279CA4C7B968B717FBB30','t':'fe','s':17156,'e':'59e5c6984c0bf6ac1a8d30e521542bd585dccfc03e68fc3dc721516c78966fff','host':'geo.captcha-delivery.com'}</script><script data-cfasync="false" src="https://ct.captcha-delivery.com/c.js"></script></body></html>
#
# URL: https://www.idealista.com/venta-viviendas/madrid/carabanchel/
# Status Code: 200
#                                                   url  \
# 0   https://www.idealista.com/venta-viviendas/madr...
# 1   https://www.idealista.com/venta-viviendas/madr...
# 2   https://www.idealista.com/venta-viviendas/madr...
# 3   https://www.idealista.com/venta-viviendas/madr...
# ...

# %%
final_data['distrito'] = final_data['url'].str.split('/').str[-2]
final_data
# Out:
#                                                    url  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 1    https://www.idealista.com/venta-viviendas/madr...
# 2    https://www.idealista.com/venta-viviendas/madr...
# 3    https://www.idealista.com/venta-viviendas/madr...
# 4    https://www.idealista.com/venta-viviendas/madr...
# ..                                                 ...
# 295  https://www.idealista.com/venta-viviendas/madr...
# 296  https://www.idealista.com/venta-viviendas/madr...
# 297  https://www.idealista.com/venta-viviendas/madr...
# 298  https://www.idealista.com/venta-viviendas/madr...
# 299  https://www.idealista.com/venta-viviendas/madr...
#
#                                                  Title     Price Currency  \
# 0       Piso en Secoya 3 D, Pau de Carabanchel, Madrid  380.000€        €
# 1     Piso en calle de Antonio López, Comillas, Madrid  475.000€        €
# 2    Dúplex en calle de Monseñor Oscar Romero, Vist...  595.000€        €
# ...

# %%
final_data['piscina'] = final_data['Description'].str.lower().str.contains('piscina')
final_data['porter'] = final_data['Description'].str.lower().str.contains('portero')
final_data['porter'] = final_data['porter'].astype(int)
# Convertir valores booleanos a 1 o 0
#final_data['piscina'] = final_data['piscina'].astype(int)
final_data['porter'].nunique()
# Out:
# 2

# %%
final_data.to_excel('idealista_data.xlsx', index=False)

# %%
final_data[final_data['porter']==1]
# Out:
#                                                    url  \
# 0    https://www.idealista.com/venta-viviendas/madr...
# 113  https://www.idealista.com/venta-viviendas/madr...
# 211  https://www.idealista.com/venta-viviendas/madr...
# 235  https://www.idealista.com/venta-viviendas/madr...
# 253  https://www.idealista.com/venta-viviendas/madr...
# 293  https://www.idealista.com/venta-viviendas/madr...
#
#                                                  Title       Price Currency  \
# 0       Piso en Secoya 3 D, Pau de Carabanchel, Madrid    380.000€        €
# 113          Piso en calle de O'Donnell, Ibiza, Madrid  1.150.000€        €
# 211                           Ático en Horcajo, Madrid    590.000€        €
# 235  Piso en calle del Corregidor Diego de Valderrá...    340.000€        €
# 253                    Piso en Chueca-Justicia, Madrid  2.600.000€        €
# 293  Piso en calle Canoa, 12, Alameda de Osuna, Madrid    385.000€        €
#
# ...

# %%
# Lista de distritos
distritos = ['Carabanchel', 'Ciudad Lineal', 'Otro', 'Latina', 'Villaverde', 'Retiro', 'Arganzuela', 'Usera', 'Vicálvaro', 'Fuencarral-El Pardo', 'Moncloa-Aravaca', 'Hortaleza', 'Tetuán', 'Chamberí', 'Moratalaz', 'Centro', 'Puente de Vallecas', 'San Blás-Canillejas', 'B.Salamanca', 'Barajas', 'Villa de Vallecas', 'Chamartín']

# URL base
url_base = 'https://www.idealista.com/venta-viviendas/madrid/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
}

#response = requests.get(url, headers=headers)

print(response.status_code)
print(response.text)
# Encabezados para la solicitud
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# Almacena los datos recopilados
all_data_2 = []

# Bucle sobre los distritos
for distrito in distritos:
    # Formatea la URL para el distrito actual
    url = url_base + distrito.replace(' ', '_').lower() + '/con-precio-hasta_450000,precio-desde_160000/'

    # Realiza la solicitud
    response = requests.get(url, headers=headers)

    print(f'URL: {url}')
    print(f'Status Code: {response.status_code}')

    if response.status_code == 200:
        # Parsea el contenido de la página con BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Encuentra todos los elementos <a> con la clase "item-link"
        title_elements = soup.find_all('a', class_='item-link')
        prices = soup.find_all('span', class_='item-price h2-simulated')
        currencies = soup.find_all('span', class_='txt-big')
        garages = soup.find_all('span', class_='item-parking')
        descriptions = soup.find_all('p', class_='ellipsis')
        details = soup.find_all('span', class_='item-detail-char')

        # Almacena los datos en listas
        titles = [title.text.strip() for title in title_elements]
        prices = [price.text.strip() for price in prices]
        currencies = [currency.text.strip() for currency in currencies]
        garages = [garage.text.strip() if garage else None for garage in garages]
        descriptions = [desc.text.strip() if desc else None for desc in descriptions]
        details = [detail.text.strip() if detail else None for detail in details]

        # Encuentra la longitud máxima
        max_length = max(len(titles), len(prices), len(currencies), len(garages), len(descriptions), len(details))

        # Rellena las listas con valores nulos si es necesario
        titles += [None] * (max_length - len(titles))
        prices += [None] * (max_length - len(prices))
        currencies += [None] * (max_length - len(currencies))
        garages += [None] * (max_length - len(garages))
        descriptions += [None] * (max_length - len(descriptions))
        details += [None] * (max_length - len(details))

        # Crea un DataFrame de pandas
        data_2 = pd.DataFrame({
            'url': [url] * max_length,
            'Title': titles,
            'Price': prices,
            'Currency': currencies,
            'Garage': garages,
            'Description': descriptions,
            'Details': details
        })

        # Muestra el DataFrame
        print(data_2)

        # Almacena los datos en la lista
        all_data_2.append(data_2)

        if not title_elements:
            print("No se encontraron elementos con la clase 'item-link'.\n")

    else:
        print(f"Error al obtener la página. Código de estado: {response.status_code}\n")

# Concatena todos los DataFrames en uno solo
final_data_2 = pd.concat(all_data_2, ignore_index=True)

# Muestra el DataFrame final
print("DataFrame Final:")
final_data_2
# Out:
# 404
# <!DOCTYPE html>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<html lang="es" env="es" username="" data-userAuth="false" class="">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <head>
# 	<title>www.idealista.com &#8212; Viviendas venta. Viviendas alquiler. Pisos. Chalets &#8212; idealista</title>
#     <meta name="description" content='¿Buscas vivienda? Economiza tiempo y dinero con idealista, el portal inmobiliario donde puedes comprar, alquilar o vender tu casa, piso, chalet, finca u oficina de forma rápida y sencilla en España'/>
# 	<meta http-equiv="pragma" content="no-cache"/>
#     <meta http-equiv="content-Type" content="text/html; charset=UTF-8"/>
# 	<meta http-equiv="Expires" content="1200"/>
# 	<meta name="ROBOTS" content="NOODP"/>
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0">
# 	<script src="https://st3.idealista.com/static/common/js/lib/jquery/jquery-1.10.2.js" defer></script>
#
#
# ...

# %%
final_data_2['piscina'] = final_data_2['Description'].str.lower().str.contains('piscina')
final_data_2['porter'] = final_data_2['Description'].str.lower().str.contains('portero')
final_data_2['porter'] = final_data_2['porter'].astype(int)
# Convertir valores booleanos a 1 o 0
#final_data['piscina'] = final_data['piscina'].astype(int)
final_data_2['porter'].nunique()
# Out:
# 2

# %%
final_data.to_excel('idealista_data_ajustado.xlsx', index=False)
